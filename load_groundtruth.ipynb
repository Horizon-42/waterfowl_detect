# %%
from scipy.io import loadmat

mat_file = "datasets/test/groundTruth_practicalTest_orthomosiac_SmithWMA.mat"
data = loadmat("datasets/test/groundTruth_practicalTest_orthomosiac_SmithWMA.mat")
print(data.keys())   # show variable names inside the MAT file
print(data["__version__"])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'None', '__function_workspace__'])
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon Mar  2 21:48:26 2020', '__version__': '1.0', '__globals__': [], 'None': MatlabOpaque([(b'Birds', b'MCOS', b'table', array([[3707764736],
#                      [         2],
#                      [         1],
#                      [         1],
#                      [         1],
#                      [         1]], dtype=uint32))              ],
#              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), '__function_workspace__': array([[ 0,  1, 73, ...,  0,  0,  0]], dtype=uint8)}
