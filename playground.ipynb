# %%
import cv2

original_image = cv2.imread("datasets/raw_datas/00_UAV-derived Thermal Waterfowl Dataset/01_Posistive Image/20180322_101536_979_R.tif")

# save image as jpg
cv2.imwrite("image1.png", original_image)
# Out:
# True
